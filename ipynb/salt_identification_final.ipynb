# %% [markdown]
# <a href="https://colab.research.google.com/github/sumittagadiya/Salt_identification/blob/main/salt_identification_update.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from tqdm.auto import tqdm
import joblib 
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.python.data.experimental import AUTOTUNE
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.transform import resize

# %%
from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import UpSampling2D
from tensorflow.keras.layers import MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import Multiply
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Add, Dense, Activation,ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D,MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.models import Model, load_model

# %%
os.chdir('/content/drive/MyDrive/SALT_Challange')
os.makedirs('TRAIN/',exist_ok=True)
os.makedirs('TEST/',exist_ok=True)
os.makedirs('FLAMINGO/',exist_ok=True)
os.makedirs('COMPETITION_DATA/',exist_ok=True)

# %%
# !ls
# Out:
# COMPETITION_DATA      FLAMINGO	    sample_submission.csv  train.csv
# competition_data.zip  flamingo.zip  TEST		   train_valid_df.pkl
# decoded_images.pkl    model_save    test.zip		   train.zip
# depths.csv	      new.ipynb     TRAIN		   Untitled1.ipynb

# %%
len(os.listdir('TRAIN/images'))
# Out:
# 4000

# %%
print('Number of train images',len(os.listdir('TRAIN/images')))
print('Number of test images',len(os.listdir('TEST/images')))
# Out:
# Number of train images 4000
# Number of test images 18000

# %%
# get image ids
train_image_ids = sorted(os.listdir('TRAIN/images'))
train_mask_ids = sorted(os.listdir('TRAIN/masks'))
# print sample
print('Examle of image ids ==> ',train_image_ids[:2])
print('Examle of image masks ==> ',train_mask_ids[:2])
# Out:
# Examle of image ids ==>  ['000e218f21.png', '008a50a2ec.png']
# Examle of image masks ==>  ['010ee525b6.png', '016fc8031c.png']

# %%
X = np.zeros((len(train_image_ids), 128, 128, 1), dtype=np.float32)
y = np.zeros((len(train_image_ids), 128, 128, 1), dtype=np.float32)

# %%
for ind, img_id in tqdm(enumerate(train_image_ids)):
    # Load images
    img = load_img("TRAIN/images/"+img_id, grayscale=True)
    x_img = img_to_array(img)
    x_img = resize(x_img, (128, 128, 1), mode = 'constant', preserve_range = True)
    # Load masks
    mask = load_img("TRAIN/masks/"+img_id, grayscale=True)
    mask = img_to_array(mask)
    mask = resize(mask, (128, 128, 1), mode = 'constant', preserve_range = True)
    # Save images
    X[ind] = x_img/255.0
    y[ind] = mask/255.0
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
X.shape
# Out:
# (4000, 128, 128, 1)

# %%
y.shape
# Out:
# (4000, 128, 128, 1)

# %%
joblib.dump((X,y),'decoded_images.pkl')
# Out:
# ['decoded_images.pkl']

# %%
X,y = joblib.load('decoded_images.pkl')

# %%
y = y.astype(bool)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
print('X_train Shape ',X_train.shape)
print('X_valid Shape', X_valid.shape)
# Out:
# X_train Shape  (3600, 128, 128, 1)
# X_valid Shape (400, 128, 128, 1)

# %%
# Visualize any randome image along with the mask
ix = np.random.randint(0, len(X_train))
has_mask = y_train[ix].max() > 0 # salt indicator

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (20, 15))

ax1.imshow(X_train[ix, ..., 0], cmap = 'seismic', interpolation = 'bilinear')
if has_mask: # if salt
    # draw a boundary(contour) in the original image separating salt and non-salt areas
    ax1.contour(y_train[ix].squeeze(), colors = 'k', linewidths = 5, levels = [0.5])
ax1.set_title('Seismic')

ax2.imshow(y_train[ix].squeeze(), cmap = 'gray', interpolation = 'bilinear')
ax2.set_title('Salt')
# Out:
# Text(0.5, 1.0, 'Salt')

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

# %%
def unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = False):
    """Function to define the UNET Model"""
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
from keras import backend as K
from tensorflow.keras.losses import binary_crossentropy

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return score

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return tf.keras.losses.binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

def bce_logdice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - K.log(1. - dice_loss(y_true, y_pred))

# %%
# code download from: https://github.com/bermanmaxim/LovaszSoftmax
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard

###############
# BINARY LOSSES
###############
def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss

def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """

    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        loss = tf.tensordot(tf.nn.elu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss, strict=True, name="loss")
    return loss
def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    logits = y_pred
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

def symmetric_lovasz(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    loss = ((lovasz_hinge(y_pred, y_true, per_image = True, ignore = None)) + \
            (lovasz_hinge(-y_pred, 1 - y_true, per_image = True, ignore = None))) /2
    return loss

# %%
input_img = Input((128, 128, 1), name='in_img')
model = unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.binary_crossentropy, metrics=[tf.keras.metrics.MeanIoU(num_classes=2)])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# in_img (InputLayer)             [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 16) 160         in_img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 128, 128, 16) 64          conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 128, 128, 16) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 16)   0           activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64, 64, 16)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 32)   4640        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 64, 32)   128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 64, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 32)   0           activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 32, 32, 32)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 64)   18496       dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 32, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 64)   0           activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 16, 16, 64)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 128)  73856       dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 128)    0           activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 8, 8, 128)    0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 256)    295168      dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 256)    1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 256)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 16, 16, 128)  295040      activation_27[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 256)  0           conv2d_transpose_4[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 16, 16, 256)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 128)  295040      dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 16, 16, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 32, 32, 64)   73792       activation_29[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_5[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 32, 32, 128)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 64)   73792       dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 32, 32, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 32, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 64, 64, 32)   18464       activation_31[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 64)   0           conv2d_transpose_6[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64, 64, 64)   0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 32)   18464       dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 64, 64, 32)   128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 64, 64, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 128, 128, 16) 4624        activation_33[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 32) 0           conv2d_transpose_7[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 128, 128, 32) 0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 128, 128, 16) 4624        dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 128, 128, 16) 64          conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 128, 128, 16) 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 128, 128, 1)  17          activation_35[0][0]
# ==================================================================================================
# Total params: 1,179,121
# Trainable params: 1,177,649
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
#!rm -rf 'model_save'
#del model

# %%
os.makedirs('model_save/',exist_ok=True)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10, verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint('model_save/best_model.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
X_train = np.append(X_train, [np.fliplr(x) for x in X_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)

# %%
history = model.fit(X_train, y_train, batch_size=32, epochs=30, callbacks=callbacks,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/30
# 225/225 [==============================] - 17s 71ms/step - loss: 0.4145 - mean_io_u_1: 0.3728 - val_loss: 1.8061 - val_mean_io_u_1: 0.3814
#
# Epoch 00001: val_loss improved from inf to 1.80612, saving model to model_save/best_model.h5
# Epoch 2/30
# 225/225 [==============================] - 16s 69ms/step - loss: 0.2796 - mean_io_u_1: 0.3740 - val_loss: 0.3997 - val_mean_io_u_1: 0.3814
#
# Epoch 00002: val_loss improved from 1.80612 to 0.39965, saving model to model_save/best_model.h5
# Epoch 3/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.2512 - mean_io_u_1: 0.3724 - val_loss: 0.3422 - val_mean_io_u_1: 0.3814
#
# Epoch 00003: val_loss improved from 0.39965 to 0.34221, saving model to model_save/best_model.h5
# Epoch 4/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.2246 - mean_io_u_1: 0.3747 - val_loss: 0.3430 - val_mean_io_u_1: 0.3814
#
# Epoch 00004: val_loss did not improve from 0.34221
# Epoch 5/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.2237 - mean_io_u_1: 0.3742 - val_loss: 0.2086 - val_mean_io_u_1: 0.3814
#
# Epoch 00005: val_loss improved from 0.34221 to 0.20860, saving model to model_save/best_model.h5
# Epoch 6/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.2215 - mean_io_u_1: 0.3715 - val_loss: 0.2020 - val_mean_io_u_1: 0.3814
#
# Epoch 00006: val_loss improved from 0.20860 to 0.20198, saving model to model_save/best_model.h5
# Epoch 7/30
# 225/225 [==============================] - 16s 69ms/step - loss: 0.1982 - mean_io_u_1: 0.3718 - val_loss: 0.2022 - val_mean_io_u_1: 0.3814
#
# Epoch 00007: val_loss did not improve from 0.20198
# Epoch 8/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1935 - mean_io_u_1: 0.3749 - val_loss: 0.2431 - val_mean_io_u_1: 0.3814
#
# Epoch 00008: val_loss did not improve from 0.20198
# Epoch 9/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1896 - mean_io_u_1: 0.3752 - val_loss: 0.1922 - val_mean_io_u_1: 0.3814
#
# Epoch 00009: val_loss improved from 0.20198 to 0.19223, saving model to model_save/best_model.h5
# Epoch 10/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1816 - mean_io_u_1: 0.3781 - val_loss: 0.2188 - val_mean_io_u_1: 0.3814
#
# Epoch 00010: val_loss did not improve from 0.19223
# Epoch 11/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1744 - mean_io_u_1: 0.3746 - val_loss: 0.1856 - val_mean_io_u_1: 0.3814
#
# Epoch 00011: val_loss improved from 0.19223 to 0.18561, saving model to model_save/best_model.h5
# Epoch 12/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1631 - mean_io_u_1: 0.3737 - val_loss: 0.2528 - val_mean_io_u_1: 0.3814
#
# Epoch 00012: val_loss did not improve from 0.18561
# Epoch 13/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1615 - mean_io_u_1: 0.3757 - val_loss: 0.1778 - val_mean_io_u_1: 0.3814
#
# Epoch 00013: val_loss improved from 0.18561 to 0.17778, saving model to model_save/best_model.h5
# Epoch 14/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1605 - mean_io_u_1: 0.3748 - val_loss: 0.2004 - val_mean_io_u_1: 0.3866
#
# Epoch 00014: val_loss did not improve from 0.17778
# Epoch 15/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1631 - mean_io_u_1: 0.3763 - val_loss: 0.2847 - val_mean_io_u_1: 0.3814
#
# Epoch 00015: val_loss did not improve from 0.17778
# Epoch 16/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1520 - mean_io_u_1: 0.3727 - val_loss: 0.1693 - val_mean_io_u_1: 0.3814
#
# Epoch 00016: val_loss improved from 0.17778 to 0.16933, saving model to model_save/best_model.h5
# Epoch 17/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1476 - mean_io_u_1: 0.3737 - val_loss: 0.3147 - val_mean_io_u_1: 0.3814
#
# Epoch 00017: val_loss did not improve from 0.16933
# Epoch 18/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1430 - mean_io_u_1: 0.3749 - val_loss: 0.1500 - val_mean_io_u_1: 0.3814
#
# Epoch 00018: val_loss improved from 0.16933 to 0.14999, saving model to model_save/best_model.h5
# Epoch 19/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1344 - mean_io_u_1: 0.3776 - val_loss: 0.1987 - val_mean_io_u_1: 0.3814
#
# Epoch 00019: val_loss did not improve from 0.14999
# Epoch 20/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1301 - mean_io_u_1: 0.3705 - val_loss: 0.1847 - val_mean_io_u_1: 0.3937
#
# Epoch 00020: val_loss did not improve from 0.14999
# Epoch 21/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1294 - mean_io_u_1: 0.3751 - val_loss: 0.1862 - val_mean_io_u_1: 0.3827
#
# Epoch 00021: val_loss did not improve from 0.14999
# Epoch 22/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1261 - mean_io_u_1: 0.3711 - val_loss: 0.1561 - val_mean_io_u_1: 0.3814
#
# Epoch 00022: val_loss did not improve from 0.14999
# Epoch 23/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1249 - mean_io_u_1: 0.3753 - val_loss: 0.2948 - val_mean_io_u_1: 0.3825
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00023: val_loss did not improve from 0.14999
# Epoch 24/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.1046 - mean_io_u_1: 0.3760 - val_loss: 0.1447 - val_mean_io_u_1: 0.3814
#
# Epoch 00024: val_loss improved from 0.14999 to 0.14469, saving model to model_save/best_model.h5
# Epoch 25/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.0874 - mean_io_u_1: 0.3746 - val_loss: 0.1493 - val_mean_io_u_1: 0.3815
#
# Epoch 00025: val_loss did not improve from 0.14469
# Epoch 26/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.0900 - mean_io_u_1: 0.3711 - val_loss: 0.1521 - val_mean_io_u_1: 0.3815
#
# Epoch 00026: val_loss did not improve from 0.14469
# Epoch 27/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.0849 - mean_io_u_1: 0.3738 - val_loss: 0.1564 - val_mean_io_u_1: 0.3818
#
# Epoch 00027: val_loss did not improve from 0.14469
# Epoch 28/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.0815 - mean_io_u_1: 0.3740 - val_loss: 0.1553 - val_mean_io_u_1: 0.3814
#
# Epoch 00028: val_loss did not improve from 0.14469
# Epoch 29/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.0838 - mean_io_u_1: 0.3723 - val_loss: 0.1578 - val_mean_io_u_1: 0.3816
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00029: val_loss did not improve from 0.14469
# Epoch 30/30
# 225/225 [==============================] - 15s 68ms/step - loss: 0.0810 - mean_io_u_1: 0.3747 - val_loss: 0.1589 - val_mean_io_u_1: 0.3816
#
# Epoch 00030: val_loss did not improve from 0.14469

# %%
model_json = model.to_json()
with open('model_save/unet_model.json','w') as json_file:
    json_file.write(model_json)
print('Model saved to disk in json format')
# Out:
# Model saved to disk in json format

# %%
model.load_weights('model_save/best_model.h5')

# %%
model.evaluate(X_valid, y_valid, verbose=1)
# Out:
# 13/13 [==============================] - 13s 508ms/step - loss: 0.1291 - mean_io_u: 0.3838
# [0.1446862369775772, 0.3814437985420227]

# %%
preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_valid, verbose=1)
# Out:
# 113/113 [==============================] - 4s 37ms/step
# 13/13 [==============================] - 0s 38ms/step

# %%
preds_train_th = (preds_train > 0.5).astype(np.uint8)
preds_val_th = (preds_val > 0.5).astype(np.uint8)

# %%
def plot_sample(X, y, prediction, binary_prediction, index=None):
    """Function to plot the results"""
    if index is None:
        index = random.randint(0, len(X))

    has_mask = y[index].max() > 0

    fig, ax = plt.subplots(1, 4, figsize=(20, 10))
    # plot origiba seismic image
    ax[0].imshow(X[index, ..., 0], cmap='seismic')
    # if mask
    if has_mask:
        # draw seperation line
        ax[0].contour(y[index].squeeze(), colors='k', levels=[0.5])
    ax[0].set_title('Seismic')

    # plot original mask image
    ax[1].imshow(y[index].squeeze())
    ax[1].set_title('Salt')
    
    # plot predicted image
    ax[2].imshow(prediction[index].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[2].contour(y[index].squeeze(), colors='k', levels=[0.5])
    ax[2].set_title('Salt Predicted')
    
    # plot binary predicted image
    ax[3].imshow(binary_prediction[index].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[3].contour(y[index].squeeze(), colors='k', levels=[0.5])
    ax[3].set_title('Salt Predicted binary');

# %% [markdown]
# # prediction on train data

# %%
plot_sample(X_train, y_train, preds_train, preds_train_th, index=50)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_th, index=5)

# %%
plot_sample(X_train, y_train, preds_train1, preds_train_th1, index=10)

# %% [markdown]
# # Try different Model

# %%
# Build U-Net model
inputs = Input((128, 128, 1))

c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (inputs)
c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (p1)
c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (p2)
c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (p3)
c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (p4)
c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (c5)

u6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (u6)
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (c6)

u7 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (u7)
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (c7)

u8 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (u8)
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (c8)

u9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (u9)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.binary_crossentropy,
              metrics=[tf.keras.metrics.Accuracy(name='accuracy'),
                       my_iou_metric])
model.summary()
# Out:
# Model: "model_18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_342 (Conv2D)             (None, 128, 128, 8)  80          input_14[0][0]
# __________________________________________________________________________________________________
# conv2d_343 (Conv2D)             (None, 128, 128, 8)  584         conv2d_342[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_72 (MaxPooling2D) (None, 64, 64, 8)    0           conv2d_343[0][0]
# __________________________________________________________________________________________________
# conv2d_344 (Conv2D)             (None, 64, 64, 16)   1168        max_pooling2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_345 (Conv2D)             (None, 64, 64, 16)   2320        conv2d_344[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_73 (MaxPooling2D) (None, 32, 32, 16)   0           conv2d_345[0][0]
# __________________________________________________________________________________________________
# conv2d_346 (Conv2D)             (None, 32, 32, 32)   4640        max_pooling2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_347 (Conv2D)             (None, 32, 32, 32)   9248        conv2d_346[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_74 (MaxPooling2D) (None, 16, 16, 32)   0           conv2d_347[0][0]
# __________________________________________________________________________________________________
# conv2d_348 (Conv2D)             (None, 16, 16, 64)   18496       max_pooling2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_349 (Conv2D)             (None, 16, 16, 64)   36928       conv2d_348[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_75 (MaxPooling2D) (None, 8, 8, 64)     0           conv2d_349[0][0]
# __________________________________________________________________________________________________
# conv2d_350 (Conv2D)             (None, 8, 8, 128)    73856       max_pooling2d_75[0][0]
# __________________________________________________________________________________________________
# conv2d_351 (Conv2D)             (None, 8, 8, 128)    147584      conv2d_350[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_72 (Conv2DTran (None, 16, 16, 64)   32832       conv2d_351[0][0]
# __________________________________________________________________________________________________
# concatenate_72 (Concatenate)    (None, 16, 16, 128)  0           conv2d_transpose_72[0][0]
#                                                                  conv2d_349[0][0]
# __________________________________________________________________________________________________
# conv2d_352 (Conv2D)             (None, 16, 16, 64)   73792       concatenate_72[0][0]
# __________________________________________________________________________________________________
# conv2d_353 (Conv2D)             (None, 16, 16, 64)   36928       conv2d_352[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_73 (Conv2DTran (None, 32, 32, 32)   8224        conv2d_353[0][0]
# __________________________________________________________________________________________________
# concatenate_73 (Concatenate)    (None, 32, 32, 64)   0           conv2d_transpose_73[0][0]
#                                                                  conv2d_347[0][0]
# __________________________________________________________________________________________________
# conv2d_354 (Conv2D)             (None, 32, 32, 32)   18464       concatenate_73[0][0]
# __________________________________________________________________________________________________
# conv2d_355 (Conv2D)             (None, 32, 32, 32)   9248        conv2d_354[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_74 (Conv2DTran (None, 64, 64, 16)   2064        conv2d_355[0][0]
# __________________________________________________________________________________________________
# concatenate_74 (Concatenate)    (None, 64, 64, 32)   0           conv2d_transpose_74[0][0]
#                                                                  conv2d_345[0][0]
# __________________________________________________________________________________________________
# conv2d_356 (Conv2D)             (None, 64, 64, 16)   4624        concatenate_74[0][0]
# __________________________________________________________________________________________________
# conv2d_357 (Conv2D)             (None, 64, 64, 16)   2320        conv2d_356[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_75 (Conv2DTran (None, 128, 128, 8)  520         conv2d_357[0][0]
# __________________________________________________________________________________________________
# concatenate_75 (Concatenate)    (None, 128, 128, 16) 0           conv2d_transpose_75[0][0]
#                                                                  conv2d_343[0][0]
# __________________________________________________________________________________________________
# conv2d_358 (Conv2D)             (None, 128, 128, 8)  1160        concatenate_75[0][0]
# __________________________________________________________________________________________________
# conv2d_359 (Conv2D)             (None, 128, 128, 8)  584         conv2d_358[0][0]
# __________________________________________________________________________________________________
# conv2d_360 (Conv2D)             (None, 128, 128, 1)  9           conv2d_359[0][0]
# ==================================================================================================
# Total params: 485,673
# Trainable params: 485,673
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#input_img = Input((128, 128, 1), name='in_img')
#model = unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)
#model.compile(optimizer=tf.keras.optimizers.SGD(momentum=0.9,nesterov=True), loss=bce_dice_loss, metrics=[tf.keras.metrics.MeanIoU(num_classes=2)])

# %%
# !rm -rf 'model_save_3/'
del model

# %%
os.makedirs('model_save_3/',exist_ok=True)

# %%
float(True)
# Out:
# 1.0

# %%
def get_iou_vector(A, B):
    # Numpy version    
    batch_size = A.shape[0]
    metric = 0.0
    for batch in range(batch_size):
        t, p = A[batch], B[batch]
        true = np.sum(t)
        pred = np.sum(p)
        
        # deal with empty mask first
        if true == 0:
            metric += (pred == 0)
            continue
        
        # non empty mask case.  Union is never empty 
        # hence it is safe to divide by its number of pixels
        intersection = np.sum(t * p)
        union = true + pred - intersection
        iou = intersection / union
        
        # iou metrric is a stepwise approximation of the real iou over 0.5
        iou = np.floor(max(0, (iou - 0.45)*20)) / 10
        
        metric += iou
        
    # teake the average over all images in batch
    metric /= batch_size
    return metric


def my_iou_metric(label, pred):
    # Tensorflow version
    return tf.py_function(get_iou_vector, [label, float(pred > 0.5)], tf.float64)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10, verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint('model_save_3/best_model.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
Y = y.astype(float)

# %%
Y_train = y_train.astype(float)
Y_valid = y_valid.astype(float)

# %%
X1 = np.append(X, [np.fliplr(x) for x in X], axis=0)
Y1 = np.append(Y, [np.fliplr(x) for x in Y], axis=0)

# %%
X1.shape
# Out:
# (8000, 128, 128, 1)

# %%
history = model.fit(X1, Y1, batch_size=16, validation_split=0.1,
                    epochs=50, callbacks=callbacks,shuffle=True)
# Out:
# Epoch 1/50
# 450/450 [==============================] - 17s 34ms/step - loss: 0.5472 - accuracy: 0.0000e+00 - my_iou_metric: 0.3785 - val_loss: 0.3901 - val_accuracy: 0.0000e+00 - val_my_iou_metric: 0.5000
#
# Epoch 00001: val_loss improved from inf to 0.39006, saving model to model_save_3/best_model.h5
# Epoch 2/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.3836 - accuracy: 1.0276e-04 - my_iou_metric: 0.5150 - val_loss: 0.3074 - val_accuracy: 5.6259e-04 - val_my_iou_metric: 0.5502
#
# Epoch 00002: val_loss improved from 0.39006 to 0.30738, saving model to model_save_3/best_model.h5
# Epoch 3/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.3082 - accuracy: 0.0016 - my_iou_metric: 0.5640 - val_loss: 0.2392 - val_accuracy: 0.0048 - val_my_iou_metric: 0.6469
#
# Epoch 00003: val_loss improved from 0.30738 to 0.23916, saving model to model_save_3/best_model.h5
# Epoch 4/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.2698 - accuracy: 0.0037 - my_iou_metric: 0.6069 - val_loss: 0.2366 - val_accuracy: 0.0035 - val_my_iou_metric: 0.6643
#
# Epoch 00004: val_loss improved from 0.23916 to 0.23657, saving model to model_save_3/best_model.h5
# Epoch 5/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.2257 - accuracy: 0.0056 - my_iou_metric: 0.6426 - val_loss: 0.1864 - val_accuracy: 2.9655e-04 - val_my_iou_metric: 0.6729
#
# Epoch 00005: val_loss improved from 0.23657 to 0.18643, saving model to model_save_3/best_model.h5
# Epoch 6/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.2070 - accuracy: 0.0067 - my_iou_metric: 0.6548 - val_loss: 0.1677 - val_accuracy: 0.0163 - val_my_iou_metric: 0.6879
#
# Epoch 00006: val_loss improved from 0.18643 to 0.16770, saving model to model_save_3/best_model.h5
# Epoch 7/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.1983 - accuracy: 0.0091 - my_iou_metric: 0.6525 - val_loss: 0.1672 - val_accuracy: 0.0096 - val_my_iou_metric: 0.7039
#
# Epoch 00007: val_loss improved from 0.16770 to 0.16725, saving model to model_save_3/best_model.h5
# Epoch 8/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.1824 - accuracy: 0.0151 - my_iou_metric: 0.6739 - val_loss: 0.1553 - val_accuracy: 0.0245 - val_my_iou_metric: 0.7038
#
# Epoch 00008: val_loss improved from 0.16725 to 0.15526, saving model to model_save_3/best_model.h5
# Epoch 9/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.1666 - accuracy: 0.0214 - my_iou_metric: 0.6800 - val_loss: 0.1684 - val_accuracy: 5.5122e-04 - val_my_iou_metric: 0.7011
#
# Epoch 00009: val_loss did not improve from 0.15526
# Epoch 10/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.1663 - accuracy: 0.0165 - my_iou_metric: 0.6732 - val_loss: 0.1651 - val_accuracy: 0.0040 - val_my_iou_metric: 0.6976
#
# Epoch 00010: val_loss did not improve from 0.15526
# Epoch 11/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.1567 - accuracy: 0.0187 - my_iou_metric: 0.6932 - val_loss: 0.1579 - val_accuracy: 0.0086 - val_my_iou_metric: 0.6996
#
# Epoch 00011: val_loss did not improve from 0.15526
# Epoch 12/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.1549 - accuracy: 0.0162 - my_iou_metric: 0.6850 - val_loss: 0.1426 - val_accuracy: 0.0451 - val_my_iou_metric: 0.7064
#
# Epoch 00012: val_loss improved from 0.15526 to 0.14258, saving model to model_save_3/best_model.h5
# Epoch 13/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.1421 - accuracy: 0.0293 - my_iou_metric: 0.7009 - val_loss: 0.1373 - val_accuracy: 0.0220 - val_my_iou_metric: 0.7344
#
# Epoch 00013: val_loss improved from 0.14258 to 0.13732, saving model to model_save_3/best_model.h5
# Epoch 14/50
# 450/450 [==============================] - 15s 34ms/step - loss: 0.1436 - accuracy: 0.0264 - my_iou_metric: 0.7096 - val_loss: 0.1673 - val_accuracy: 0.0303 - val_my_iou_metric: 0.6854
#
# Epoch 00014: val_loss did not improve from 0.13732
# Epoch 15/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.1353 - accuracy: 0.0316 - my_iou_metric: 0.7146 - val_loss: 0.1449 - val_accuracy: 0.0222 - val_my_iou_metric: 0.7143
#
# Epoch 00015: val_loss did not improve from 0.13732
# Epoch 16/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.1270 - accuracy: 0.0358 - my_iou_metric: 0.7095 - val_loss: 0.1595 - val_accuracy: 0.0278 - val_my_iou_metric: 0.6966
#
# Epoch 00016: val_loss did not improve from 0.13732
# Epoch 17/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.1305 - accuracy: 0.0302 - my_iou_metric: 0.7052 - val_loss: 0.1589 - val_accuracy: 0.0688 - val_my_iou_metric: 0.7046
#
# Epoch 00017: val_loss did not improve from 0.13732
# Epoch 18/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.1280 - accuracy: 0.0376 - my_iou_metric: 0.7158 - val_loss: 0.1505 - val_accuracy: 0.0561 - val_my_iou_metric: 0.7111
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00018: val_loss did not improve from 0.13732
# Epoch 19/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.1038 - accuracy: 0.0559 - my_iou_metric: 0.7338 - val_loss: 0.1340 - val_accuracy: 0.0420 - val_my_iou_metric: 0.7211
#
# Epoch 00019: val_loss improved from 0.13732 to 0.13396, saving model to model_save_3/best_model.h5
# Epoch 20/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.0878 - accuracy: 0.0603 - my_iou_metric: 0.7566 - val_loss: 0.1374 - val_accuracy: 0.0586 - val_my_iou_metric: 0.7161
#
# Epoch 00020: val_loss did not improve from 0.13396
# Epoch 21/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.0862 - accuracy: 0.0711 - my_iou_metric: 0.7497 - val_loss: 0.1366 - val_accuracy: 0.0589 - val_my_iou_metric: 0.7091
#
# Epoch 00021: val_loss did not improve from 0.13396
# Epoch 22/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.0800 - accuracy: 0.0787 - my_iou_metric: 0.7499 - val_loss: 0.1416 - val_accuracy: 0.0666 - val_my_iou_metric: 0.7090
#
# Epoch 00022: val_loss did not improve from 0.13396
# Epoch 23/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.0792 - accuracy: 0.0770 - my_iou_metric: 0.7576 - val_loss: 0.1456 - val_accuracy: 0.0780 - val_my_iou_metric: 0.7075
#
# Epoch 00023: val_loss did not improve from 0.13396
# Epoch 24/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.0736 - accuracy: 0.0910 - my_iou_metric: 0.7650 - val_loss: 0.1434 - val_accuracy: 0.0754 - val_my_iou_metric: 0.7094
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00024: val_loss did not improve from 0.13396
# Epoch 25/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.0698 - accuracy: 0.0873 - my_iou_metric: 0.7645 - val_loss: 0.1484 - val_accuracy: 0.0813 - val_my_iou_metric: 0.7060
#
# Epoch 00025: val_loss did not improve from 0.13396
# Epoch 26/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.0726 - accuracy: 0.0935 - my_iou_metric: 0.7637 - val_loss: 0.1506 - val_accuracy: 0.0827 - val_my_iou_metric: 0.7050
#
# Epoch 00026: val_loss did not improve from 0.13396
# Epoch 27/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.0689 - accuracy: 0.0963 - my_iou_metric: 0.7682 - val_loss: 0.1525 - val_accuracy: 0.0855 - val_my_iou_metric: 0.7020
#
# Epoch 00027: val_loss did not improve from 0.13396
# Epoch 28/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.0705 - accuracy: 0.0933 - my_iou_metric: 0.7613 - val_loss: 0.1529 - val_accuracy: 0.0859 - val_my_iou_metric: 0.7005
#
# Epoch 00028: val_loss did not improve from 0.13396
# Epoch 29/50
# 450/450 [==============================] - 15s 33ms/step - loss: 0.0693 - accuracy: 0.0995 - my_iou_metric: 0.7605 - val_loss: 0.1537 - val_accuracy: 0.0860 - val_my_iou_metric: 0.7025
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00029: val_loss did not improve from 0.13396
# Epoch 00029: early stopping

# %%
plt.plot(history.history['my_iou_metric'][1:])
plt.plot(history.history['val_my_iou_metric'][1:])
plt.title('IoU metric')
plt.ylabel('val_my_iou_metric')
plt.xlabel('epoch')
plt.legend(['train','Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'][1:])
plt.plot(history.history['val_loss'][1:])
plt.title('Train-valid loss')
plt.ylabel('val_loss')
plt.xlabel('epoch')
plt.legend(['train','Validation'], loc='upper left')
plt.show()

# %%
model.evaluate(X_valid, y_valid, verbose=1)
# Out:
# 13/13 [==============================] - 1s 35ms/step - loss: 0.0706 - accuracy: 0.0975 - my_iou_metric: 0.7942
# [0.0705859437584877, 0.0974632278084755, 0.7942308187484741]

# %%
preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_valid, verbose=1)
# Out:
# 113/113 [==============================] - 1s 11ms/step
# 13/13 [==============================] - 0s 10ms/step

# %%
preds_train_th = (preds_train > 0.5).astype(np.uint8)
preds_val_th = (preds_val > 0.5).astype(np.uint8)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_th, index=500)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_th, index=7)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_th, index=10)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_th, index=11)

# %% [markdown]
# # Trial

# %%
# Build U-Net model
inputs = Input((128, 128, 1))

c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (inputs)
c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (p1)
c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (p2)
c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (p3)
c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (p4)
c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (c5)

u6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (u6)
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (c6)

u7 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (u7)
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (c7)

u8 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (u8)
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (c8)

u9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (u9)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

new_model = Model(inputs=[inputs], outputs=[outputs])
new_model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.binary_crossentropy,
                  metrics=[tf.keras.metrics.MeanIoU(num_classes=2,name='iou_tf'),
                           my_iou_metric])
new_model.summary()
# Out:
# Model: "model_28"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_18 (InputLayer)           [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_437 (Conv2D)             (None, 128, 128, 8)  80          input_18[0][0]
# __________________________________________________________________________________________________
# conv2d_438 (Conv2D)             (None, 128, 128, 8)  584         conv2d_437[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_92 (MaxPooling2D) (None, 64, 64, 8)    0           conv2d_438[0][0]
# __________________________________________________________________________________________________
# conv2d_439 (Conv2D)             (None, 64, 64, 16)   1168        max_pooling2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_440 (Conv2D)             (None, 64, 64, 16)   2320        conv2d_439[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_93 (MaxPooling2D) (None, 32, 32, 16)   0           conv2d_440[0][0]
# __________________________________________________________________________________________________
# conv2d_441 (Conv2D)             (None, 32, 32, 32)   4640        max_pooling2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_442 (Conv2D)             (None, 32, 32, 32)   9248        conv2d_441[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_94 (MaxPooling2D) (None, 16, 16, 32)   0           conv2d_442[0][0]
# __________________________________________________________________________________________________
# conv2d_443 (Conv2D)             (None, 16, 16, 64)   18496       max_pooling2d_94[0][0]
# __________________________________________________________________________________________________
# conv2d_444 (Conv2D)             (None, 16, 16, 64)   36928       conv2d_443[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_95 (MaxPooling2D) (None, 8, 8, 64)     0           conv2d_444[0][0]
# __________________________________________________________________________________________________
# conv2d_445 (Conv2D)             (None, 8, 8, 128)    73856       max_pooling2d_95[0][0]
# __________________________________________________________________________________________________
# conv2d_446 (Conv2D)             (None, 8, 8, 128)    147584      conv2d_445[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_92 (Conv2DTran (None, 16, 16, 64)   32832       conv2d_446[0][0]
# __________________________________________________________________________________________________
# concatenate_92 (Concatenate)    (None, 16, 16, 128)  0           conv2d_transpose_92[0][0]
#                                                                  conv2d_444[0][0]
# __________________________________________________________________________________________________
# conv2d_447 (Conv2D)             (None, 16, 16, 64)   73792       concatenate_92[0][0]
# __________________________________________________________________________________________________
# conv2d_448 (Conv2D)             (None, 16, 16, 64)   36928       conv2d_447[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_93 (Conv2DTran (None, 32, 32, 32)   8224        conv2d_448[0][0]
# __________________________________________________________________________________________________
# concatenate_93 (Concatenate)    (None, 32, 32, 64)   0           conv2d_transpose_93[0][0]
#                                                                  conv2d_442[0][0]
# __________________________________________________________________________________________________
# conv2d_449 (Conv2D)             (None, 32, 32, 32)   18464       concatenate_93[0][0]
# __________________________________________________________________________________________________
# conv2d_450 (Conv2D)             (None, 32, 32, 32)   9248        conv2d_449[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_94 (Conv2DTran (None, 64, 64, 16)   2064        conv2d_450[0][0]
# __________________________________________________________________________________________________
# concatenate_94 (Concatenate)    (None, 64, 64, 32)   0           conv2d_transpose_94[0][0]
#                                                                  conv2d_440[0][0]
# __________________________________________________________________________________________________
# conv2d_451 (Conv2D)             (None, 64, 64, 16)   4624        concatenate_94[0][0]
# __________________________________________________________________________________________________
# conv2d_452 (Conv2D)             (None, 64, 64, 16)   2320        conv2d_451[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_95 (Conv2DTran (None, 128, 128, 8)  520         conv2d_452[0][0]
# __________________________________________________________________________________________________
# concatenate_95 (Concatenate)    (None, 128, 128, 16) 0           conv2d_transpose_95[0][0]
#                                                                  conv2d_438[0][0]
# __________________________________________________________________________________________________
# conv2d_453 (Conv2D)             (None, 128, 128, 8)  1160        concatenate_95[0][0]
# __________________________________________________________________________________________________
# conv2d_454 (Conv2D)             (None, 128, 128, 8)  584         conv2d_453[0][0]
# __________________________________________________________________________________________________
# conv2d_455 (Conv2D)             (None, 128, 128, 1)  9           conv2d_454[0][0]
# ==================================================================================================
# Total params: 485,673
# Trainable params: 485,673
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# !rm -rf 'new_model_save'
#del new_model

# %%
os.makedirs('new_model_save/',exist_ok=True)

# %%
callbacks = [
    #tf.keras.callbacks.EarlyStopping(patience=10, verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint('new_model_save/best_model.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
X_train_new = np.append(X_train, [np.fliplr(x) for x in X_train], axis=0)
Y_train_new = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)

# %%
X_train_new.shape
# Out:
# (7200, 128, 128, 1)

# %%
Y_train_new = Y_train_new.astype(float)

# %%
y_valid = y_valid.astype(float)

# %%
history_new = new_model.fit(X_train_new, Y_train_new, batch_size=16, 
                         validation_data=(X_valid,y_valid),
                         epochs=30, callbacks=callbacks,shuffle=True)
# Out:
# Epoch 1/30
